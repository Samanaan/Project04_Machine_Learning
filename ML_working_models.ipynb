# %% [markdown]
# ## Packages needed for ML

# %%
#pip install tabulate

# %%
#pip install seaborn

# %%
#pip install xgboost

# %% [markdown]
# ## Import Modules

# %%
import sqlite3

# %%
import pandas as pd
from datetime import datetime
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
from tabulate import tabulate
import seaborn as sns

# %% [markdown]
# ## Importing data and creating SQLite database

# %%
# reading in CSV (NOTE: This is the data after the ETL is done)
retail_df_csv = pd.read_csv("Resources/retail_price_cleaned.csv")

# %%
# path and name for database and connecting the db
conn = sqlite3.connect("Resources/pricing_opt.db")
# creating the table "retail" from the dataframe
retail_df_csv.to_sql('retail',conn,index=False,if_exists='replace')

# %%
query = "SELECT * FROM retail;"
retail_df = pd.read_sql(query,conn)
conn.close()
retail_df.head()
# Out:
#   product_id product_category_name  month_year  qty_sold  total_price  \
# 0       bed1        bed_bath_table  01-05-2017         1        45.95
# 1       bed1        bed_bath_table  01-06-2017         3       137.85
# 2       bed1        bed_bath_table  01-07-2017         6       275.70
# 3       bed1        bed_bath_table  01-08-2017         4       183.80
# 4       bed1        bed_bath_table  01-09-2017         2        91.90
#
#    freight_price  unit_price  product_rating  no_customers  month  ...  \
# 0      15.100000       45.95             4.0            57      5  ...
# 1      12.933333       45.95             4.0            61      6  ...
# 2      14.840000       45.95             4.0           123      7  ...
# 3      14.287500       45.95             4.0            90      8  ...
# 4      15.100000       45.95             4.0            54      9  ...
#
#    comp1_price  comp1_prod_rating  comp1_freight_price  comp2_price  \
# 0         89.9                3.9            15.011897   215.000000
# 1         89.9                3.9            14.769216   209.000000
# 2         89.9                3.9            13.993833   205.000000
# 3         89.9                3.9            14.656757   199.509804
# 4         89.9                3.9            18.776522   163.398710
#
#    comp2_prod_rating  comp2_freight_price  comp3_price  comp3_prod_rating  \
# 0                4.4             8.760000        45.95                4.0
# 1                4.4            21.322000        45.95                4.0
# 2                4.4            22.195932        45.95                4.0
# 3                4.4            19.412885        45.95                4.0
# 4                4.4            24.324687        45.95                4.0
#
#    comp3_freight_price  lag_price
# 0            15.100000      45.90
# 1            12.933333      45.95
# 2            14.840000      45.95
# 3            14.287500      45.95
# 4            15.100000      45.95
#
# [5 rows x 23 columns]

# %%
# retail_df = pd.read_csv("Resources/retail_price_cleaned.csv")
#retail_df.info()

# %%
retail_df.columns
# Out:
# Index(['product_id', 'product_category_name', 'month_year', 'qty_sold',
#        'total_price', 'freight_price', 'unit_price', 'product_rating',
#        'no_customers', 'month', 'year', 'seasonality', 'volume', 'comp1_price',
#        'comp1_prod_rating', 'comp1_freight_price', 'comp2_price',
#        'comp2_prod_rating', 'comp2_freight_price', 'comp3_price',
#        'comp3_prod_rating', 'comp3_freight_price', 'lag_price'],
#       dtype='object')

# %%
# combining 'year' and 'month' to datetime
retail_df['date'] = pd.to_datetime(retail_df[['year', 'month']].assign(day=1))

# Sort the DataFrame by the new datetime column
retail_df = retail_df.sort_values('date')

retail_df.head()
# Out:
#     product_id product_category_name  month_year  qty_sold  total_price  \
# 389    health7         health_beauty  01-01-2017         1        64.99
# 339    health5         health_beauty  01-01-2017         8      2799.20
# 438       bed2        bed_bath_table  01-02-2017         2       179.80
# 236    garden8          garden_tools  01-02-2017         1       179.99
# 58     health9         health_beauty  01-02-2017        11       219.89
#
#      freight_price  unit_price  product_rating  no_customers  month  ...  \
# 389      11.060000       64.99             3.9             9      1  ...
# 339      22.901250      349.90             4.3             9      1  ...
# 438      13.020000       89.90             3.9             2      2  ...
# 236      33.540000      179.99             4.2             3      2  ...
# 58       11.750909       19.99             4.3            19      2  ...
#
#      comp1_prod_rating  comp1_freight_price  comp2_price  comp2_prod_rating  \
# 389                3.9            11.060000        64.99                3.9
# 339                4.3            22.901250       349.90                4.3
# 438                3.9            13.020000        89.90                3.9
# 236                4.2            33.540000       179.99                4.2
# 58                 4.3            11.750909        19.99                4.3
#
#      comp2_freight_price  comp3_price  comp3_prod_rating  comp3_freight_price  \
# 389            11.060000        64.99                3.9               11.060
# 339            22.901250        64.99                3.9               11.060
# 438            13.020000        89.90                3.9               13.020
# 236            33.540000       179.99                4.2               33.540
# 58             11.750909        64.99                3.9               15.348
#
#      lag_price       date
# 389      64.94 2017-01-01
# 339     349.85 2017-01-01
# 438      89.85 2017-02-01
# 236     179.94 2017-02-01
# 58       19.94 2017-02-01
#
# [5 rows x 24 columns]

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

# Define the window size
window_size = 5

grouped = retail_df.groupby('product_id')

table_data = []
mse_scores = []
predicted_unit_prices = []

for group_key, group_data in grouped:
    # set features and target variable
    features = group_data[['qty_sold', 'total_price', 'freight_price', 'product_rating',
                           'no_customers', 'seasonality', 'volume', 'comp1_price',
                           'comp1_prod_rating', 'comp1_freight_price', 'comp2_price',
                           'comp2_prod_rating', 'comp2_freight_price', 'comp3_price',
                           'comp3_prod_rating', 'comp3_freight_price', 'lag_price']]

    target = group_data['unit_price']
    
    num_samples = len(features)
    predicted_unit_prices = []
    
    # sliding window training and testing
    for i in range(window_size, num_samples):
        # Define the periods for training and testing
        train_start = i - window_size
        train_end = i
        test_start = i
        test_end = i + 1
        
        # Split data into training and testing sets
        features_train = features.iloc[train_start:train_end]
        target_train = target.iloc[train_start:train_end]
        features_test = features.iloc[test_start:test_end]
        target_test = target.iloc[test_start:test_end]
        
        # Train the model
        model = LinearRegression()
        model.fit(features_train, target_train)
        
        # Make predictions
        y_pred = model.predict(features_test)
        
        # Evaluate using Mean Squared Error
        mse = mean_squared_error(target_test, y_pred)
        mse_scores.append(mse)
        
        # Calculate and store the predicted unit prices
        predicted_unit_price = y_pred[0]
        predicted_unit_prices.append(predicted_unit_price)
        
        table_data.append([group_key, i+1, predicted_unit_price, mse])

# Print table
table_headers = ["Product ID", "Sample", "Predicted Price", "MSE"]
print(tabulate(table_data, headers=table_headers, floatfmt=(".0f", ".0f", ".2f", ".2f")))

avg_mse = np.mean(mse_scores)
avg_predicted_unit_price = np.mean(predicted_unit_prices)
print(f"Average MSE: {avg_mse:.2f}")
print(f"Average Predicted Unit Price: {avg_predicted_unit_price:.2f}")


        
#         print(f"Product {group_key}, Sample {i+1} - Predicted Price: {predicted_unit_price:.2f}, MSE: {mse:.2f}")

# avg_mse = np.mean(mse_scores)
# avg_predicted_unit_price = np.mean(predicted_unit_prices)
# print(f"Average MSE: {avg_mse:.2f}")
# print(f"Average Predicted Unit Price: {avg_predicted_unit_price:.2f}")
# Out:
# Product ID      Sample    Predicted Price       MSE
# ------------  --------  -----------------  --------
# bed1                 6              45.95      0.00
# bed1                 7              45.95     29.36
# bed1                 8              41.98      3.98
# bed1                 9              22.08    320.69
# bed1                10              40.42      0.18
# bed1                11              39.32      0.45
# bed1                12              39.89      0.01
# bed1                13              39.99      0.00
# bed1                14              39.99      0.00
# bed1                15              39.99      0.00
# bed1                16              39.99      0.56
# bed2                 6              89.90      0.00
# bed2                 7              89.90      0.00
# bed2                 8              89.90      0.00
# bed2                 9              89.90      0.00
# bed2                10              89.90      0.00
# bed2                11              89.90      1.99
# bed2                12              89.68      7.75
# bed2                13              88.21      1.71
# bed2                14              87.02      0.01
# bed2                15              87.15      4.42
# bed2                16              84.52      0.76
# bed2                17              85.30     29.13
# bed2                18              78.24      0.09
# bed2                19              74.16      0.03
# bed3                 6              98.00     35.97
# bed3                 7              89.44      2.06
# bed3                 8              84.92     11.05
# bed3                 9              85.01      0.01
# bed3                10              85.28      0.15
# bed3                11              87.77      8.22
# bed4                 6              46.09      3.27
# bed4                 7              48.18      0.08
# bed4                 8              48.72      0.68
# bed4                 9              48.32      0.17
# bed4                10              49.00      1.20
# computers1           6              98.71      0.04
# computers1           7             103.64     22.46
# computers1           8             100.81      3.65
# computers1           9             114.86    591.68
# computers1          10              89.64     23.82
# computers1          11              90.00      6.27
# computers1          12              88.15     34.26
# computers1          13              89.99    288.50
# computers1          14              61.25     25.90
# computers1          15              79.60      0.09
# computers2           6              84.63     15.71
# computers2           7              81.53      2.98
# computers2           8              77.28      2.63
# computers2           9              78.22      0.10
# computers2          10              77.40      0.25
# computers3           6             135.98      3.67
# computers3           7             137.33      0.33
# computers3           8             139.08     17.44
# computers3           9             131.20      3.26
# computers3          10             128.34     21.43
# computers4           6             143.21      6.24
# computers4           7             146.49     30.21
# computers4           8             155.10      0.16
# computers4           9             137.77    149.37
# computers4          10             155.87     34.60
# computers4          11             149.05     55.74
# computers4          12             154.98     35.80
# computers4          13             152.45    265.87
# computers4          14             134.48    183.84
# computers4          15             119.67      0.46
# computers4          16             115.55      1.13
# computers4          17             111.71     68.60
# computers4          18             114.50     30.15
# computers5           6              91.69     13.59
# computers5           7              98.58     75.41
# computers5           8              95.24    266.99
# computers6           6             149.94      0.00
# computers6           7             149.90      0.00
# computers6           8             149.90      0.00
# consoles1            6              23.58      0.84
# consoles1            7              26.67     33.95
# consoles1            8              33.01      0.26
# consoles1            9              34.75      0.10
# consoles1           10              32.47     13.94
# consoles1           11              36.49      0.08
# consoles1           12              35.53      0.45
# consoles2            6              23.70      0.64
# consoles2            7              23.49     12.55
# consoles2            8              24.10     70.50
# consoles2            9              33.05      0.09
# consoles2           10              33.29      0.83
# cool1                6              99.62      0.14
# cool1                7              99.99      0.00
# cool1                8              99.99      0.00
# cool1                9              99.99      0.00
# cool1               10              99.99      0.00
# cool1               11              99.99      0.00
# cool1               12              99.99      0.00
# cool1               13              99.99      0.00
# cool1               14              99.99      0.00
# cool1               15              99.99    102.55
# cool2                6             129.99    170.63
# cool2                7             120.11      0.02
# cool2                8             129.95      0.00
# cool2                9             128.76      1.51
# garden4             11              52.34      0.52
# garden4             12              53.71     14.48
# garden4             13              54.83     24.29
# garden4             14              49.48      0.17
# garden5              6              99.29      3.81
# garden5              7              98.38      0.38
# garden5              8             108.59     91.99
# garden5              9             128.15    849.55
# garden5             10             100.05      1.11
# garden5             11              98.15      1.82
# garden5             12              99.28      2.97
# garden5             13             103.89      8.37
# garden5             14             100.96      0.00
# garden6              6              59.90      0.00
# garden6              7              59.90     56.15
# garden6              8              56.66      2.42
# garden6              9              60.78    118.36
# garden6             10              49.54      1.02
# garden6             11              54.26      0.13
# garden6             12              54.33      0.18
# garden6             13              57.66     18.03
# garden6             14              55.93     36.38
# garden6             15              52.84      8.59
# garden6             16              49.54      0.14
# garden7              6              59.90      0.00
# garden7              7              59.90     73.58
# garden7              8              56.26      0.51
# garden7              9              58.63     76.30
# garden7             10              53.63      4.98
# garden7             11              54.89      0.98
# garden7             12              58.12     17.84
# garden7             13              50.95      3.81
# garden7             14              54.30     19.32
# garden7             15              47.64      5.09
# garden7             16              49.78      0.01
# garden8              6             179.99     16.00
# garden8              7             186.51      1.79
# garden8              8             184.22     27.22
# garden8              9             178.07      8.50
# garden8             10             176.41      6.73
# garden8             11             157.88    446.06
# garden8             12             173.61    213.53
# garden8             13             166.78    771.49
# garden8             14             123.66    235.26
# garden9              6              59.90      0.00
# garden9              7              59.90      0.00
# garden9              8              59.90     42.52
# garden9              9              57.56      3.22
# garden9             10              56.91     49.20
# garden9             11              49.33      2.86
# garden9             12              54.21      0.09
# garden9             13              55.75      3.44
# garden9             14              51.87      0.48
# garden9             15              58.04     66.34
# garden9             16              51.22      1.74
# garden9             17              49.94      0.00
# health1              6              84.99      0.00
# health1              7              84.99      0.00
# health1              8              84.99      0.00
# health1              9              84.99      0.00
# health10             6              49.73      3.16
# health10             7              50.34      0.14
# health2              6             325.00      0.00
# health2              7             325.00      0.00
# health2              8             325.00      0.80
# health2              9             325.05     24.46
# health2             10             325.80     17.67
# health2             11             326.27     13.90
# health2             12             330.55      0.30
# health2             13             323.33     44.51
# health3              6             132.70     94.25
# health3              7             121.20      3.19
# health3              8             120.36      6.93
# health4              6              29.90      0.00
# health4              7              29.90      0.00
# health4              8              29.90      0.00
# health4              9              29.90      0.00
# health4             10              29.90      0.00
# health4             11              29.90      0.00
# health5              6             349.90      0.00
# health5              7             349.90      0.00
# health5              8             349.90      0.00
# health5              9             349.90      0.00
# health5             10             349.90      0.00
# health5             11             349.90    770.82
# health5             12             332.71    295.34
# health5             13             331.84    326.21
# health5             14             335.29    213.41
# health5             15             337.93    143.34
# health5             16             325.96    572.91
# health5             17             349.90      5.52
# health5             18             350.73    176.18
# health5             19             367.35     11.19
# health5             20             364.24      0.06
# health6              6              67.10      0.01
# health6              7              66.68      0.10
# health7              6              64.99     38.32
# health7              7              58.03      1.51
# health7              8              55.97      9.14
# health7              9              58.28      0.50
# health7             10              59.97      0.97
# health7             11              59.12      0.02
# health7             12              59.37      0.15
# health7             13              58.99      0.00
# health7             14              58.99      0.00
# health7             15              58.99      0.00
# watches7            11             327.31   6627.07
# watches7            12             291.92  15023.80
# watches8             6             119.35    960.44
# watches8             7             110.35   1212.34
# watches8             8             131.28    456.00
# watches8             9             153.82     11.02
# watches8            10             151.04     47.69
# Average MSE: 167.58
# Average Predicted Unit Price: 133.17

# %%
from collections import defaultdict

# Calculate the average predicted unit price and MSE for each product ID
product_avg_predicted_prices = defaultdict(list)
for entry in table_data:
    group_key = entry[0]
    avg_predicted_price = entry[2]
    avg_mse = entry[3]
    product_avg_predicted_prices[group_key].append((avg_predicted_price, avg_mse, entry[1]))

# Find the optimal prices for each product ID based on minimum average MSE
optimal_prices = {}
for group_key, avg_mse_list in product_avg_predicted_prices.items():
    min_avg_mse_entry = min(avg_mse_list, key=lambda x: x[1])
    optimal_price = min_avg_mse_entry[0]
    min_mse = min_avg_mse_entry[1]
    min_mse_sample = min_avg_mse_entry[2]
    optimal_prices[group_key] = (optimal_price, min_mse, min_mse_sample)

# Prepare the final table data for optimal prices
optimal_table_data = []
for group_key, (optimal_price, min_mse, min_mse_sample) in optimal_prices.items():
    optimal_table_data.append([group_key, optimal_price, min_mse, min_mse_sample])

# Print the table for optimal prices
optimal_table_headers = ["Product ID", "Optimal Price", "Min MSE", "Sample with Min MSE"]
print(tabulate(optimal_table_data, headers=optimal_table_headers, floatfmt=(".0f", ".2f", ".2f", ".0f")))
# Out:
# Product ID      Optimal Price    Min MSE    Sample with Min MSE
# ------------  ---------------  ---------  ---------------------
# bed1                    45.95       0.00                      6
# bed2                    89.90       0.00                      6
# bed3                    85.01       0.01                      9
# bed4                    48.18       0.08                      7
# computers1              98.71       0.04                      6
# computers2              78.22       0.10                      9
# computers3             137.33       0.33                      7
# computers4             155.10       0.16                      8
# computers5              91.69      13.59                      6
# computers6             149.90       0.00                      7
# consoles1               36.49       0.08                     11
# consoles2               33.05       0.09                      9
# cool1                   99.99       0.00                      7
# cool2                  129.99       0.00                     13
# cool3                   60.56      19.72                      7
# cool4                  172.34       5.53                      9
# cool5                   99.99       0.00                      6
# furniture1              35.20       0.04                     12
# furniture2              70.10       0.04                     10
# furniture3              38.65       0.06                      7
# furniture4              99.90       0.00                      6
# garden1                122.79       7.79                      6
# garden10                59.90       0.00                      6
# garden2                 59.90       0.00                      6
# garden3                 97.74       5.05                     17
# garden4                 50.16       0.04                      8
# garden5                100.96       0.00                     14
# garden6                 59.90       0.00                      6
# garden7                 59.90       0.00                      6
# garden8                186.51       1.79                      7
# garden9                 59.90       0.00                      6
# health1                 84.99       0.00                      6
# health10                50.34       0.14                      7
# health2                325.00       0.00                      6
# health3                121.20       3.19                      7
# health4                 29.90       0.00                      6
# health5                349.90       0.00                      6
# health6                 67.10       0.01                      6
# health7                 58.99       0.00                     13
# health8                 89.99       0.00                      6
# health9                 19.99       0.00                      6
# perfumery1              56.99       0.00                      6
# perfumery2             117.92       0.05                      8
# watches1               153.32       2.09                     12
# watches2               144.98       1.02                      9
# watches3                78.00       0.00                      6
# watches4               105.10       0.01                      9
# watches5               209.13      22.50                      9
# watches6               114.98      16.18                     12
# watches7               278.53       4.55                      9
# watches8               153.82      11.02                      9

# %%
#Save to table
table_df_1 = pd.DataFrame(table_data, columns=["Product ID", "Sample", "Predicted Price", "MSE"])
table_df_1.to_csv("Output/SW_predicted_prices_mse.csv", index=False)

# %%
#Save optimal prices to csv
optimal_table_df_1 = pd.DataFrame(optimal_table_data, columns=["Product ID", "Optimal Price", "Min MSE", "Sample with Min MSE"])
optimal_table_df_1.to_csv("Output/SW_optimal_prices.csv", index=False)

# %% [markdown]
# # Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

# Define the window size
window_size = 5

grouped = retail_df.groupby('product_id')

table_data = []
mse_scores = []
predicted_unit_prices = []

for group_key, group_data in grouped:
    # set features and target variable
    features = group_data[['qty_sold', 'total_price', 'freight_price', 'product_rating',
                           'no_customers', 'seasonality', 'volume', 'comp1_price',
                           'comp1_prod_rating', 'comp1_freight_price', 'comp2_price',
                           'comp2_prod_rating', 'comp2_freight_price', 'comp3_price',
                           'comp3_prod_rating', 'comp3_freight_price', 'lag_price']]

    target = group_data['unit_price']
    
    num_samples = len(features)
    predicted_unit_prices = []
    
    # sliding window training and testing
    for i in range(window_size, num_samples):
        # Define the periods for training and testing
        train_start = i - window_size
        train_end = i
        test_start = i
        test_end = i + 1
        
        # Split data into training and testing sets
        features_train = features.iloc[train_start:train_end]
        target_train = target.iloc[train_start:train_end]
        features_test = features.iloc[test_start:test_end]
        target_test = target.iloc[test_start:test_end]
        
        # Train the model
        model = RandomForestRegressor(n_estimators=50, random_state=78)
        model.fit(features_train, target_train)
        
        # Make predictions
        y_pred = model.predict(features_test)
        
        # Evaluate using Mean Squared Error
        mse = mean_squared_error(target_test, y_pred)
        mse_scores.append(mse)
        
        # Calculate and store the predicted unit prices
        predicted_unit_price = y_pred[0]
        predicted_unit_prices.append(predicted_unit_price)
        
        table_data.append([group_key, i+1, predicted_unit_price, mse])

# Print table
table_headers = ["Product ID", "Sample", "Predicted Price", "MSE"]
print(tabulate(table_data, headers=table_headers, floatfmt=(".0f", ".0f", ".2f", ".2f")))

avg_mse = np.mean(mse_scores)
avg_predicted_unit_price = np.mean(predicted_unit_prices)
print(f"Average MSE: {avg_mse:.2f}")
print(f"Average Predicted Unit Price: {avg_predicted_unit_price:.2f}")


        
#         print(f"Product {group_key}, Sample {i+1} - Predicted Price: {predicted_unit_price:.2f}, MSE: {mse:.2f}")

# avg_mse = np.mean(mse_scores)
# avg_predicted_unit_price = np.mean(predicted_unit_prices)
# print(f"Average MSE: {avg_mse:.2f}")
# print(f"Average Predicted Unit Price: {avg_predicted_unit_price:.2f}")
# Out:
# Product ID      Sample    Predicted Price       MSE
# ------------  --------  -----------------  --------
# bed1                 6              45.95      0.00
# bed1                 7              45.95     29.36
# bed1                 8              45.73     32.99
# bed1                 9              41.07      1.17
# bed1                10              41.96      3.89
# bed1                11              40.26      0.07
# bed1                12              40.09      0.01
# bed1                13              39.99      0.00
# bed1                14              39.99      0.00
# bed1                15              39.99      0.00
# bed1                16              39.99      0.56
# bed2                 6              89.90      0.00
# bed2                 7              89.90      0.00
# bed2                 8              89.90      0.00
# bed2                 9              89.90      0.00
# bed2                10              89.90      0.00
# bed2                11              89.90      1.99
# bed2                12              89.31      5.79
# bed2                13              88.34      2.07
# bed2                14              87.52      0.39
# bed2                15              87.82      7.71
# bed2                16              86.95     10.91
# bed2                17              85.91     36.08
# bed2                18              83.83     34.79
# bed2                19              81.60     57.81
# bed3                 6              95.98     15.81
# bed3                 7              96.07     27.03
# bed3                 8              92.65     19.43
# bed3                 9              91.01     37.38
# bed3                10              88.51     13.01
# bed3                11              88.24     11.15
# bed4                 6              45.80      4.43
# bed4                 7              46.46      2.07
# bed4                 8              46.54      1.85
# bed4                 9              47.42      0.23
# bed4                10              47.90      0.00
# computers1           6              99.82      0.85
# computers1           7             102.20     10.89
# computers1           8             101.10      4.84
# computers1           9             100.00     89.61
# computers1          10              94.88    102.58
# computers1          11              92.75     27.59
# computers1          12              90.62     11.45
# computers1          13              90.79    316.45
# computers1          14              82.65    265.89
# computers1          15              74.94     24.57
# computers2           6              90.98    106.34
# computers2           7              86.50     44.82
# computers2           8              80.57      2.80
# computers2           9              79.60      2.89
# computers2          10              78.98      1.17
# computers3           6             146.08     66.92
# computers3           7             140.73      8.02
# computers3           8             139.27     19.11
# computers3           9             137.94     24.38
# computers3          10             135.55      6.68
# computers4           6             147.59      3.56
# computers4           7             147.82     17.40
# computers4           8             151.33     11.35
# computers4           9             151.72      3.00
# computers4          10             150.29      0.09
# computers4          11             149.34     51.42
# computers4          12             151.34      5.48
# computers4          13             151.41    233.04
# computers4          14             148.39    754.59
# computers4          15             146.31    745.61
# computers4          16             128.71    202.06
# computers4          17             124.29     18.52
# computers4          18             120.03      0.00
# computers5           6              96.75     76.60
# computers5           7              89.22      0.46
# computers5           8              84.44     30.65
# computers6           6             149.98      0.01
# computers6           7             149.90      0.00
# computers6           8             149.90      0.00
# consoles1            6              21.73      7.69
# consoles1            7              22.73     95.41
# consoles1            8              27.38     26.19
# consoles1            9              28.80     39.12
# consoles1           10              32.58     13.09
# consoles1           11              34.24      3.84
# consoles1           12              35.66      0.29
# consoles2            6              22.15      5.50
# consoles2            7              22.86     17.42
# consoles2            8              23.88     74.30
# consoles2            9              27.34     29.21
# consoles2           10              29.92     18.33
# cool1                6              99.42      0.33
# cool1                7              99.99      0.00
# cool1                8              99.99      0.00
# cool1                9              99.99      0.00
# cool1               10              99.99      0.00
# cool1               11              99.99      0.00
# cool1               12              99.99      0.00
# cool1               13              99.99      0.00
# cool1               14              99.99      0.00
# cool1               15              99.99    102.55
# cool2                6             129.99    170.63
# cool2                7             122.94      8.68
# cool2                8             123.13     47.03
# cool2                9             125.62     19.08
# cool2               10             126.24     14.07
# cool2               11             126.70     10.82
# cool2               12             127.79      4.84
# cool2               13             129.99      0.00
# cool3                6              34.01    960.38
# cool3                7              49.83    230.13
# cool4                6             143.21    565.52
# cool4                7             159.14    318.48
# cool4                8             163.62    103.81
# cool4                9             170.42      0.18
# cool5                6              99.99      0.00
# cool5                7              99.99      0.00
# cool5                8              99.99      0.00
# cool5                9              99.99      0.00
# cool5               10              99.99      0.00
# cool5               11              99.99      0.00
# cool5               12              99.99      4.15
# cool5               13              98.93    202.71
# furniture1           6              37.75      0.42
# furniture1           7              38.06      0.12
# furniture1           8              38.12      6.95
# furniture1           9              37.43      5.88
# furniture1          10              36.19      1.41
# garden7              6              59.90      0.00
# garden7              7              59.90     73.58
# garden7              8              59.56      6.65
# garden7              9              57.88     63.75
# garden7             10              55.87     20.00
# garden7             11              53.97      0.00
# garden7             12              53.59      0.09
# garden7             13              53.82      0.84
# garden7             14              52.65      7.56
# garden7             15              51.56      2.76
# garden7             16              50.46      0.31
# garden8              6             179.99     16.00
# garden8              7             180.55     53.35
# garden8              8             182.68     13.52
# garden8              9             181.04     34.69
# garden8             10             179.37      0.14
# garden8             11             181.36      5.58
# garden8             12             180.50    462.35
# garden8             13             168.46    867.98
# garden8             14             154.29    233.85
# garden9              6              59.90      0.00
# garden9              7              59.90      0.00
# garden9              8              59.90     42.52
# garden9              9              58.20      5.92
# garden9             10              56.73     46.60
# garden9             11              54.25     10.42
# garden9             12              53.83      0.01
# garden9             13              53.23      0.44
# garden9             14              53.37      0.64
# garden9             15              52.78      8.30
# garden9             16              51.40      2.24
# garden9             17              50.35      0.21
# health1              6              84.99      0.00
# health1              7              84.99      0.00
# health1              8              84.99      0.00
# health1              9              84.99      0.00
# health10             6              51.75      0.06
# health10             7              50.25      0.21
# health2              6             325.00      0.00
# health2              7             325.00      0.00
# health2              8             325.00      0.80
# health2              9             325.18     23.25
# health2             10             326.46     12.53
# health2             11             328.11      3.58
# health2             12             329.64      0.13
# health2             13             328.03      3.89
# health3              6             116.02     48.63
# health3              7             119.51     12.08
# health3              8             119.05     15.50
# health4              6              29.90      0.00
# health4              7              29.90      0.00
# health4              8              29.90      0.00
# health4              9              29.90      0.00
# health4             10              29.90      0.00
# health4             11              29.90      0.00
# health5              6             349.90      0.00
# health5              7             349.90      0.00
# health5              8             349.90      0.00
# health5              9             349.90      0.00
# health5             10             349.90      0.00
# health5             11             349.90    770.82
# health5             12             348.23      2.77
# health5             13             344.90     24.97
# health5             14             340.46     89.11
# health5             15             344.90     24.97
# health5             16             346.57     11.10
# health5             17             349.90      5.52
# health5             18             350.04    194.85
# health5             19             355.12     78.91
# health5             20             357.61     40.86
# health6              6              65.27      2.96
# health6              7              64.93      4.24
# health7              6              64.99     38.32
# health7              7              63.63     19.11
# health7              8              61.28      5.24
# health7              9              60.54      2.40
# health7             10              60.71      2.95
# health7             11              58.97      0.00
# health7             12              59.01      0.00
# health7             13              58.99      0.00
# health7             14              58.99      0.00
# health7             15              58.99      0.00
# health7             16              58.99      0.00
# health7             17              58.99      0.00
# health7             18              58.99      0.00
# health7             19              58.99      0.00
# health7             20              58.99      0.00
# health8              6              89.99      0.00
# health8              7              89.99      0.00
# health8              8              89.99      0.00
# health8              9              89.99      0.00
# health8             10              89.99      0.00
# health8             11              89.99      0.00
# health8             12              89.99     39.06
# health8             13              88.74     76.56
# health8             14              86.96     48.65
# health8             15              81.74      3.06
# health8             16              81.49      2.25
# health8             17              81.34      2.19
# health9              6              19.99      0.00
# health9              7              19.99     11.61
# health9              8              21.49      6.25
# health9              9              22.33      2.74
# health9             10              22.14      3.44
# health9             11              23.68      0.10
# health9             12              23.95      0.00
# health9             13              23.99      0.00
# health9             14              23.99      0.00
# health9             15              23.99      0.00
# health9             16              23.99      0.00
# health9             17              23.99      0.00
# health9             18              23.99      0.00
# perfumery1           6              56.99      0.00
# perfumery1           7              56.99      0.00
# perfumery1           8              56.99      0.00
# perfumery1           9              56.99      0.00
# perfumery1          10              56.99     42.25
# perfumery1          11              55.04     25.50
# perfumery1          12              53.46     12.04
# perfumery1          13              52.14      4.62
# perfumery2           6             124.89     48.83
# perfumery2           7             120.90      9.08
# perfumery2           8             121.86     17.28
# perfumery2           9             117.89      0.01
# perfumery2          10             117.88      4.07
# perfumery2          11             118.75      0.19
# perfumery2          12             118.46      0.06
# perfumery2          13             118.63      2.96
# watches1             6             206.09   1723.81
# watches1             7             199.66   1077.96
# watches1             8             179.31     23.82
# watches1             9             189.14     10.08
# watches1            10             184.11    221.69
# watches1            11             179.68      5.36
# watches1            12             180.26    805.73
# watches1            13             173.71    556.01
# watches1            14             162.55    901.35
# watches1            15             156.86    347.41
# watches1            16             152.61      5.69
# watches1            17             150.25     22.04
# watches2             6             161.40    434.40
# watches2             7             162.82    190.99
# watches2             8             150.77      5.14
# watches2             9             148.16      4.69
# watches2            10             146.22    495.43
# watches2            11             136.50    299.70
# watches2            12             136.16    324.86
# watches2            13             128.36    133.08
# watches2            14             131.11     61.87
# watches2            15             132.43     31.00
# watches3             6              78.00      0.00
# watches3             7              78.00      0.00
# watches3             8              78.00      0.00
# watches3             9              78.00      0.00
# watches3            10              78.00      0.00
# watches3            11              78.00      0.00
# watches3            12              78.00      0.00
# watches3            13              78.00      0.00
# watches3            14              78.00      0.00
# watches3            15              78.00      0.03
# watches4             6             107.15      4.63
# watches4             7             106.42      2.01
# watches4             8             106.39      1.94
# watches4             9             105.48      0.23
# watches4            10             105.09      0.01
# watches5             6             214.76     36.15
# watches5             7             212.08     40.89
# watches5             8             209.64     42.90
# watches5             9             207.01      6.88
# watches5            10             209.19    103.84
# watches6             6             152.97    399.00
# watches6             7             144.10     24.05
# watches6             8             140.74    156.10
# watches6             9             138.77    454.91
# watches6            10             127.01    456.10
# watches6            11             116.34    157.34
# watches6            12             125.66     44.29
# watches6            13             118.40      0.00
# watches6            14             117.06     25.56
# watches7             6             342.19      5.23
# watches7             7             343.49     12.31
# watches7             8             346.30   1479.96
# watches7             9             330.13   2446.73
# watches7            10             318.36   3527.70
# watches7            11             316.91   5041.77
# watches7            12             283.51  13032.20
# watches8             6             196.97   2173.68
# watches8             7             183.15   1442.87
# watches8             8             180.91    799.30
# watches8             9             165.96     77.82
# watches8            10             154.28     13.43
# Average MSE: 137.00
# Average Predicted Unit Price: 176.25

# %%
# Calculate the average predicted unit price and MSE for each product ID
product_avg_predicted_prices = defaultdict(list)
for entry in table_data:
    group_key = entry[0]
    avg_predicted_price = entry[2]
    avg_mse = entry[3]
    product_avg_predicted_prices[group_key].append((avg_predicted_price, avg_mse, entry[1]))

# Find the optimal prices for each product ID based on minimum average MSE
optimal_prices = {}
for group_key, avg_mse_list in product_avg_predicted_prices.items():
    min_avg_mse_entry = min(avg_mse_list, key=lambda x: x[1])
    optimal_price = min_avg_mse_entry[0]
    min_mse = min_avg_mse_entry[1]
    min_mse_sample = min_avg_mse_entry[2]
    optimal_prices[group_key] = (optimal_price, min_mse, min_mse_sample)

# Prepare the final table data for optimal prices
optimal_table_data = []
for group_key, (optimal_price, min_mse, min_mse_sample) in optimal_prices.items():
    optimal_table_data.append([group_key, optimal_price, min_mse, min_mse_sample])

# Print the table for optimal prices
optimal_table_headers = ["Product ID", "Optimal Price", "Min MSE", "Sample with Min MSE"]
print(tabulate(optimal_table_data, headers=optimal_table_headers, floatfmt=(".0f", ".2f", ".2f", ".0f")))
# Out:
# Product ID      Optimal Price    Min MSE    Sample with Min MSE
# ------------  ---------------  ---------  ---------------------
# bed1                    39.99       0.00                     13
# bed2                    89.90       0.00                      6
# bed3                    88.24      11.15                     11
# bed4                    47.90       0.00                     10
# computers1              99.82       0.85                      6
# computers2              78.98       1.17                     10
# computers3             135.55       6.68                     10
# computers4             120.03       0.00                     18
# computers5              89.22       0.46                      7
# computers6             149.90       0.00                      7
# consoles1               35.66       0.29                     12
# consoles2               22.15       5.50                      6
# cool1                   99.99       0.00                      7
# cool2                  129.99       0.00                     13
# cool3                   49.83     230.13                      7
# cool4                  170.42       0.18                      9
# cool5                   99.99       0.00                      6
# furniture1              35.08       0.01                     13
# furniture2              70.32       0.17                     10
# furniture3              35.37       0.14                     12
# furniture4              99.90       0.00                      6
# garden1                 98.39       0.00                     18
# garden10                59.90       0.00                      6
# garden2                 59.90       0.00                      6
# garden3                111.00       1.00                     15
# garden4                 53.42       0.23                     10
# garden5                100.71       0.08                     14
# garden6                 59.90       0.00                      6
# garden7                 59.90       0.00                      6
# garden8                179.37       0.14                     10
# garden9                 59.90       0.00                      6
# health1                 84.99       0.00                      6
# health10                51.75       0.06                      6
# health2                325.00       0.00                      6
# health3                119.51      12.08                      7
# health4                 29.90       0.00                      6
# health5                349.90       0.00                      6
# health6                 65.27       2.96                      6
# health7                 58.99       0.00                     13
# health8                 89.99       0.00                      6
# health9                 19.99       0.00                      6
# perfumery1              56.99       0.00                      6
# perfumery2             117.89       0.01                      9
# watches1               179.68       5.36                     11
# watches2               148.16       4.69                      9
# watches3                78.00       0.00                      6
# watches4               105.09       0.01                     10
# watches5               207.01       6.88                      9
# watches6               118.40       0.00                     13
# watches7               342.19       5.23                      6
# watches8               154.28      13.43                     10

# %%
#Save predicted prices to csv
table_df_2 = pd.DataFrame(table_data, columns=["Product ID", "Sample", "Predicted Price", "MSE"])
table_df_2.to_csv("Output/RF_predicted_prices_mse.csv", index=False)

# %%
#Save optimal prices to csv
optimal_table_df_2 = pd.DataFrame(optimal_table_data, columns=["Product ID", "Optimal Price", "Min MSE", "Sample with Min MSE"])
optimal_table_df_2.to_csv("Output/RF_optimal_prices.csv", index=False)

# %% [markdown]
# # XGBoost Model

# %%
## use XGBOOST model
import xgboost as xgb
# Define the window size
window_size = 5
grouped = retail_df.groupby('product_id')
table_data = []
mse_scores = []
predicted_unit_prices = []
for group_key, group_data in grouped:
    # set features and target variable
    features = group_data[['qty_sold', 'total_price', 'freight_price', 'product_rating',
                           'no_customers', 'seasonality', 'volume', 'comp1_price',
                           'comp1_prod_rating', 'comp1_freight_price', 'comp2_price',
                           'comp2_prod_rating', 'comp2_freight_price', 'comp3_price',
                           'comp3_prod_rating', 'comp3_freight_price', 'lag_price']]
                           
    target = group_data['unit_price']
    num_samples = len(features)
    predicted_unit_prices = []
    # sliding window training and testing
    for i in range(window_size, num_samples):
        # Define the periods for training and testing
        train_start = i - window_size
        train_end = i
        test_start = i
        test_end = i + 1
        # Split data into training and testing sets
        features_train = features.iloc[train_start:train_end]
        target_train = target.iloc[train_start:train_end]
        features_test = features.iloc[test_start:test_end]
        target_test = target.iloc[test_start:test_end]
        # Train the model
        model = xgb.XGBRegressor(n_estimators=50, random_state=78)
        model.fit(features_train, target_train)
        # Make predictions
        y_pred = model.predict(features_test)
        # Evaluate using Mean Squared Error
        mse = mean_squared_error(target_test, y_pred)
        mse_scores.append(mse)
        # Calculate and store the predicted unit prices
        predicted_unit_price = y_pred[0]
        predicted_unit_prices.append(predicted_unit_price)
        table_data.append([group_key, i+1, predicted_unit_price, mse])
# Print table
table_headers = ["Product ID", "Sample", "Predicted Price", "MSE"]
print(tabulate(table_data, headers=table_headers, floatfmt=(".0f", ".0f", ".2f", ".2f")))
avg_mse = np.mean(mse_scores)
avg_predicted_unit_price = np.mean(predicted_unit_prices)
print(f"Average MSE: {avg_mse:.2f}")
print(f"Average Predicted Unit Price: {avg_predicted_unit_price:.2f}")
# Out:
# Product ID      Sample    Predicted Price       MSE
# ------------  --------  -----------------  --------
# bed1                 6              45.95      0.00
# bed1                 7              45.95     29.36
# bed1                 8              45.95     35.52
# bed1                 9              40.53      0.29
# bed1                10              39.99      0.00
# bed1                11              39.99      0.00
# bed1                12              39.99      0.00
# bed1                13              39.99      0.00
# bed1                14              39.99      0.00
# bed1                15              39.99      0.00
# bed1                16              39.99      0.56
# bed2                 6              89.90      0.00
# bed2                 7              89.90      0.00
# bed2                 8              89.90      0.00
# bed2                 9              89.90      0.00
# bed2                10              89.90      0.00
# bed2                11              89.90      1.99
# bed2                12              89.90      9.00
# bed2                13              88.49      2.52
# bed2                14              86.90      0.00
# bed2                15              88.49     11.84
# bed2                16              86.90     10.56
# bed2                17              86.90     48.99
# bed2                18              85.04     50.57
# bed2                19              79.47     29.90
# bed3                 6              92.00      0.00
# bed3                 7              99.00     66.00
# bed3                 8              92.00     14.14
# bed3                 9              88.24     11.16
# bed3                10              87.53      6.94
# bed3                11              89.42     20.43
# bed4                 6              45.90      4.00
# bed4                 7              47.89      0.00
# bed4                 8              47.90      0.00
# bed4                 9              47.90      0.00
# bed4                10              47.90      0.00
# computers1           6              98.82      0.01
# computers1           7              98.92      0.00
# computers1           8              98.90      0.00
# computers1           9              98.90     69.99
# computers1          10              90.53     33.39
# computers1          11              98.90    129.95
# computers1          12              95.67      2.80
# computers1          13              90.95    322.18
# computers1          14              85.12    352.53
# computers1          15              91.18    127.26
# computers2           6              92.23    133.71
# computers2           7              93.58    189.79
# computers2           8              80.67      3.12
# computers2           9              78.84      0.89
# computers2          10              77.90      0.00
# computers3           6             141.86     15.70
# computers3           7             141.45     12.58
# computers3           8             140.31     29.23
# computers3           9             134.90      3.61
# watches1            15             134.26     15.67
# watches1            16             171.80    282.14
# watches1            17             150.31     22.67
# watches2             6             161.53    439.83
# watches2             7             169.90    436.64
# watches2             8             149.47      0.94
# watches2             9             149.02      9.14
# watches2            10             146.02    486.29
# watches2            11             140.53    455.47
# watches2            12             140.54    501.99
# watches2            13             148.48     73.56
# watches2            14             123.95    225.94
# watches2            15             138.98      0.95
# watches3             6              78.00      0.00
# watches3             7              78.00      0.00
# watches3             8              78.00      0.00
# watches3             9              78.00      0.00
# watches3            10              78.00      0.00
# watches3            11              78.00      0.00
# watches3            12              78.00      0.00
# watches3            13              78.00      0.00
# watches3            14              78.00      0.00
# watches3            15              78.00      0.03
# watches4             6             108.00      9.00
# watches4             7             105.00      0.00
# watches4             8             108.00      8.99
# watches4             9             105.00      0.00
# watches4            10             105.00      0.00
# watches5             6             208.40    152.97
# watches5             7             207.76      4.29
# watches5             8             203.29    166.35
# watches5             9             200.41     15.80
# watches5            10             204.94     35.32
# watches6             6             160.76    770.56
# watches6             7             147.73      1.61
# watches6             8             134.91     44.46
# watches6             9             128.24    116.70
# watches6            10             117.44    139.08
# watches6            11             105.65      3.45
# watches6            12             128.24     85.30
# watches6            13             118.95      0.34
# watches6            14             118.99     48.84
# watches7             6             339.00      0.81
# watches7             7             345.70      1.69
# watches7             8             346.55   1498.93
# watches7             9             314.90   1172.14
# watches7            10             320.69   3809.45
# watches7            11             346.94  10209.87
# watches7            12             286.03  13614.23
# watches8             6             167.64    299.33
# watches8             7             150.34     26.78
# watches8             8             229.84   5961.05
# watches8             9             152.63     20.37
# watches8            10             152.66     27.89
# Average MSE: 167.50
# Average Predicted Unit Price: 170.62

# %%
# Calculate the average predicted unit price and MSE for each product ID
product_avg_predicted_prices = defaultdict(list)
for entry in table_data:
    group_key = entry[0]
    avg_predicted_price = entry[2]
    avg_mse = entry[3]
    product_avg_predicted_prices[group_key].append((avg_predicted_price, avg_mse, entry[1]))
# Find the optimal prices for each product ID based on minimum average MSE
optimal_prices = {}
for group_key, avg_mse_list in product_avg_predicted_prices.items():
    min_avg_mse_entry = min(avg_mse_list, key=lambda x: x[1])
    optimal_price = min_avg_mse_entry[0]
    min_mse = min_avg_mse_entry[1]
    min_mse_sample = min_avg_mse_entry[2]
    optimal_prices[group_key] = (optimal_price, min_mse, min_mse_sample)
# Prepare the final table data for optimal prices
optimal_table_data = []
for group_key, (optimal_price, min_mse, min_mse_sample) in optimal_prices.items():
    optimal_table_data.append([group_key, optimal_price, min_mse, min_mse_sample])
# Print the table for optimal prices
optimal_table_headers = ["Product ID", "Optimal Price", "Min MSE", "Sample with Min MSE"]
print(tabulate(optimal_table_data, headers=optimal_table_headers, floatfmt=(".0f", ".2f", ".2f", ".0f")))
# Out:
# Product ID      Optimal Price    Min MSE    Sample with Min MSE
# ------------  ---------------  ---------  ---------------------
# bed1                    39.99       0.00                     11
# bed2                    89.90       0.00                      6
# bed3                    92.00       0.00                      6
# bed4                    47.90       0.00                     10
# computers1              98.90       0.00                      8
# computers2              77.90       0.00                     10
# computers3             133.68       0.50                     10
# computers4             149.99       0.00                     10
# computers5              88.07      84.05                      8
# computers6             149.90       0.00                      7
# consoles1               36.20       0.00                     12
# consoles2               32.74       2.14                     10
# cool1                   99.99       0.00                      7
# cool2                  129.99       0.00                     13
# cool3                   64.98       0.00                      7
# cool4                  166.97      46.75                      8
# cool5                   99.99       0.00                      6
# furniture1              35.00       0.00                     13
# furniture2              69.90       0.00                     10
# furniture3              35.00       0.00                     12
# furniture4              99.90       0.00                      6
# garden1                 89.99       0.00                     10
# garden10                59.90       0.00                      6
# garden2                 59.90       0.00                      6
# garden3                110.00       0.00                     15
# garden4                 49.90       0.00                     14
# garden5                 99.00       0.00                     10
# garden6                 59.90       0.00                      6
# garden7                 59.90       0.00                      6
# garden8                179.00       0.00                     11
# garden9                 59.90       0.00                      6
# health1                 84.99       0.00                      6
# health10                51.84       0.11                      6
# health2                325.00       0.00                      6
# health3                122.99       0.00                      8
# health4                 29.90       0.00                      6
# health5                349.90       0.00                      6
# health6                 66.01       0.96                      7
# health7                 58.99       0.00                     13
# health8                 89.99       0.00                      6
# health9                 19.99       0.00                      6
# perfumery1              56.99       0.00                      6
# perfumery2             117.90       0.01                      9
# watches1               185.96      15.66                     11
# watches2               149.47       0.94                      8
# watches3                78.00       0.00                      6
# watches4               105.00       0.00                      9
# watches5               207.76       4.29                      7
# watches6               118.95       0.34                     13
# watches7               339.00       0.81                      6
# watches8               152.63      20.37                      9

# %%
#Save predicted prices to csv
table_df_3 = pd.DataFrame(table_data, columns=["Product ID", "Sample", "Predicted Price", "MSE"])
table_df_3.to_csv("Output/XGB_predicted_prices_mse.csv", index=False)

# %%
#Save optimal prices to csv
optimal_table_df_3 = pd.DataFrame(optimal_table_data, columns=["Product ID", "Optimal Price", "Min MSE", "Sample with Min MSE"])
optimal_table_df_3.to_csv("Output/XGB_optimal_prices.csv", index=False)

# %% [markdown]
# # Linear Regression Cumulative Model

# %%
# Initial size of data for training. This will expand by "expand_size" at every loop cycle.
# This is the concept of cumulative training.
init_train_length = 5 
# Define size of testing data.
test_length = 1
# Define the step size for expansion.
expand_size = 1

grouped = retail_df.groupby('product_id')

table_data = []
mse_scores = []
predicted_unit_prices = []

# %%
# For cumulative model
for group_key, group_data in grouped:
    # Extract the group's features and target variable
    features = group_data[['qty_sold', 'total_price', 'freight_price', 'product_rating',
                           'no_customers', 'seasonality', 'volume', 'comp1_price',
                           'comp1_prod_rating', 'comp1_freight_price', 'comp2_price',
                           'comp2_prod_rating', 'comp2_freight_price', 'comp3_price',
                           'comp3_prod_rating', 'comp3_freight_price', 'lag_price']]

    target = group_data['unit_price']
   
    # debug
    print(f"Product {group_key} - Features Length: {len(features)}, Target Length: {len(target)}")
    
    # Check if there's enough data for cumulative training
    if len(features) >= init_train_length + test_length:
        predicted_unit_prices = []
        
        # cumulative training for each group
        
        i = 0       # i is the number of cumulative trainings for each product
        while init_train_length + test_length + i * expand_size <= len(features):
            # Define the periods for training and testing
            train_end = init_train_length + i * expand_size
            test_start = train_end
            test_end = train_end + test_length
            print(f"i = {i}, train_end = {train_end}, test_start = {test_start}, test_end = {test_end}")
            # Split data into training and testing sets
            #features_train = features[features.index < train_end]
            #target_train = target[target.index < train_end]
            #features_test = features[(features.index >= test_start) & (features.index < test_end)]
            #target_test = target[(target.index >= test_start) & (target.index < test_end)]
    
            features_train = features.iloc[0:train_end]
            target_train = target.iloc[0:train_end]
            features_test = features.iloc[test_start:test_end]
            target_test = target.iloc[test_start:test_end]
            
            # Train the model
            model = LinearRegression()
            model.fit(features_train, target_train)
            
            # Make predictions
            y_pred = model.predict(features_test)
            
            # Evaluate the predictions using Mean Squared Error
            mse = mean_squared_error(target_test, y_pred)
            mse_scores.append(mse)
  
            # Calculate and store the predicted unit prices
            predicted_unit_price = y_pred[0]
            predicted_unit_prices.append(predicted_unit_price)

            print(f"Product {group_key}, Period {i} - MSE: {mse:.2f}, Predicted Unit Price: {predicted_unit_price}")
            i += 1
            table_data.append([group_key, i, predicted_unit_price, mse])

    else:
        print(f"Product {group_key} - Not enough data for cumulative training")

#avg_mse = np.mean(mse_scores)
#print(f"Average MSE: {avg_mse:.2f}")

# Print table
table_headers = ["Product ID", "Sample", "Predicted Price", "MSE"]
print(tabulate(table_data, headers=table_headers, floatfmt=(".0f", ".0f", ".2f", ".2f")))

avg_mse = np.mean(mse_scores)
avg_predicted_unit_price = np.mean(predicted_unit_prices)
print(f"Average MSE: {avg_mse:.2f}")
print(f"Average Predicted Unit Price: {avg_predicted_unit_price:.2f}")
# Out:
# Product bed1 - Features Length: 16, Target Length: 16
# i = 0, train_end = 5, test_start = 5, test_end = 6
# Product bed1, Period 0 - MSE: 0.00, Predicted Unit Price: 45.95
# i = 1, train_end = 6, test_start = 6, test_end = 7
# Product bed1, Period 1 - MSE: 19.78, Predicted Unit Price: 44.97894074509583
# i = 2, train_end = 7, test_start = 7, test_end = 8
# Product bed1, Period 2 - MSE: 3.85, Predicted Unit Price: 41.951761675186944
# i = 3, train_end = 8, test_start = 8, test_end = 9
# Product bed1, Period 3 - MSE: 7.55, Predicted Unit Price: 42.7372495315555
# i = 4, train_end = 9, test_start = 9, test_end = 10
# Product bed1, Period 4 - MSE: 0.95, Predicted Unit Price: 40.96410027988912
# i = 5, train_end = 10, test_start = 10, test_end = 11
# Product bed1, Period 5 - MSE: 0.00, Predicted Unit Price: 40.03180072427809
# i = 6, train_end = 11, test_start = 11, test_end = 12
# Product bed1, Period 6 - MSE: 0.52, Predicted Unit Price: 39.268881571854294
# i = 7, train_end = 12, test_start = 12, test_end = 13
# Product bed1, Period 7 - MSE: 0.00, Predicted Unit Price: 40.00909411130164
# i = 8, train_end = 13, test_start = 13, test_end = 14
# Product bed1, Period 8 - MSE: 0.00, Predicted Unit Price: 39.99000000000003
# i = 9, train_end = 14, test_start = 14, test_end = 15
# Product bed1, Period 9 - MSE: 0.00, Predicted Unit Price: 39.99000000000006
# i = 10, train_end = 15, test_start = 15, test_end = 16
# Product bed1, Period 10 - MSE: 0.00, Predicted Unit Price: 39.24
# Product bed2 - Features Length: 19, Target Length: 19
# i = 0, train_end = 5, test_start = 5, test_end = 6
# Product bed2, Period 0 - MSE: 0.00, Predicted Unit Price: 89.9
# i = 1, train_end = 6, test_start = 6, test_end = 7
# Product bed2, Period 1 - MSE: 0.00, Predicted Unit Price: 89.89999999999999
# i = 2, train_end = 7, test_start = 7, test_end = 8
# Product bed2, Period 2 - MSE: 0.00, Predicted Unit Price: 89.89999999999999
# i = 3, train_end = 8, test_start = 8, test_end = 9
# Product bed2, Period 3 - MSE: 0.00, Predicted Unit Price: 89.9
# i = 4, train_end = 9, test_start = 9, test_end = 10
# Product bed2, Period 4 - MSE: 0.00, Predicted Unit Price: 89.9
# i = 5, train_end = 10, test_start = 10, test_end = 11
# Product bed2, Period 5 - MSE: 1.99, Predicted Unit Price: 89.9
# i = 6, train_end = 11, test_start = 11, test_end = 12
# Product bed2, Period 6 - MSE: 0.00, Predicted Unit Price: 86.9287709388953
# i = 7, train_end = 12, test_start = 12, test_end = 13
# Product bed2, Period 7 - MSE: 0.00, Predicted Unit Price: 86.86954597834519
# i = 8, train_end = 13, test_start = 13, test_end = 14
# Product bed2, Period 8 - MSE: 0.00, Predicted Unit Price: 86.90003101681522
# i = 9, train_end = 14, test_start = 14, test_end = 15
#
# i = 3, train_end = 8, test_start = 8, test_end = 9
# Product health5, Period 3 - MSE: 0.00, Predicted Unit Price: 349.9
# i = 4, train_end = 9, test_start = 9, test_end = 10
# Product health5, Period 4 - MSE: 0.00, Predicted Unit Price: 349.9
# i = 5, train_end = 10, test_start = 10, test_end = 11
# Product health5, Period 5 - MSE: 770.82, Predicted Unit Price: 349.9
# i = 6, train_end = 11, test_start = 11, test_end = 12
# Product health5, Period 6 - MSE: 152.93, Predicted Unit Price: 337.5335199776381
# i = 7, train_end = 12, test_start = 12, test_end = 13
# Product health5, Period 7 - MSE: 20.52, Predicted Unit Price: 345.3698910386866
# i = 8, train_end = 13, test_start = 13, test_end = 14
# Product health5, Period 8 - MSE: 0.00, Predicted Unit Price: 349.89999999997485
# i = 9, train_end = 14, test_start = 14, test_end = 15
# Product health5, Period 9 - MSE: 0.00, Predicted Unit Price: 349.9000000000586
# i = 10, train_end = 15, test_start = 15, test_end = 16
# Product health5, Period 10 - MSE: 0.00, Predicted Unit Price: 349.89999999999253
# i = 11, train_end = 16, test_start = 16, test_end = 17
# Product health5, Period 11 - MSE: 1.14, Predicted Unit Price: 351.1818181834534
# i = 12, train_end = 17, test_start = 17, test_end = 18
# Product health5, Period 12 - MSE: 0.04, Predicted Unit Price: 364.20981772226105
# i = 13, train_end = 18, test_start = 18, test_end = 19
# Product health5, Period 13 - MSE: 0.04, Predicted Unit Price: 364.1909494452931
# i = 14, train_end = 19, test_start = 19, test_end = 20
# Product health5, Period 14 - MSE: 3.39, Predicted Unit Price: 362.1578923563768
# Product health6 - Features Length: 7, Target Length: 7
# i = 0, train_end = 5, test_start = 5, test_end = 6
# Product health6, Period 0 - MSE: 0.01, Predicted Unit Price: 67.0954279865458
# i = 1, train_end = 6, test_start = 6, test_end = 7
# Product health6, Period 1 - MSE: 0.11, Predicted Unit Price: 66.65349691625137
# Product health7 - Features Length: 20, Target Length: 20
# i = 0, train_end = 5, test_start = 5, test_end = 6
# Product health7, Period 0 - MSE: 38.32, Predicted Unit Price: 64.99
# i = 1, train_end = 6, test_start = 6, test_end = 7
# Product health7, Period 1 - MSE: 1.62, Predicted Unit Price: 57.98522406644694
# i = 2, train_end = 7, test_start = 7, test_end = 8
# Product health7, Period 2 - MSE: 12.51, Predicted Unit Price: 55.45313587695216
# i = 3, train_end = 8, test_start = 8, test_end = 9
# Product health7, Period 3 - MSE: 0.01, Predicted Unit Price: 58.89352996695088
# i = 4, train_end = 9, test_start = 9, test_end = 10
# Product health7, Period 4 - MSE: 2.64, Predicted Unit Price: 60.61489934613168
# i = 5, train_end = 10, test_start = 10, test_end = 11
# Product health7, Period 5 - MSE: 2.69, Predicted Unit Price: 60.630422352345256
# i = 6, train_end = 11, test_start = 11, test_end = 12
# Product health7, Period 6 - MSE: 0.02, Predicted Unit Price: 58.851304140841215
# i = 7, train_end = 12, test_start = 12, test_end = 13
# Product health7, Period 7 - MSE: 0.00, Predicted Unit Price: 58.99133797974941
# i = 8, train_end = 13, test_start = 13, test_end = 14
# Product health7, Period 8 - MSE: 0.00, Predicted Unit Price: 58.99000000000001
# i = 9, train_end = 14, test_start = 14, test_end = 15
# Product health7, Period 9 - MSE: 0.00, Predicted Unit Price: 58.98999999999996
# i = 10, train_end = 15, test_start = 15, test_end = 16
# Product health7, Period 10 - MSE: 0.00, Predicted Unit Price: 58.989999999999974
# i = 11, train_end = 16, test_start = 16, test_end = 17
# Product health7, Period 11 - MSE: 0.00, Predicted Unit Price: 58.98999999999999
# i = 12, train_end = 17, test_start = 17, test_end = 18
# Product health7, Period 12 - MSE: 0.00, Predicted Unit Price: 58.99000000000001
# i = 13, train_end = 18, test_start = 18, test_end = 19
# Product health7, Period 13 - MSE: 0.00, Predicted Unit Price: 58.98999999999999
# i = 14, train_end = 19, test_start = 19, test_end = 20
# Product health7, Period 14 - MSE: 0.00, Predicted Unit Price: 58.98999999999998
# Product health8 - Features Length: 17, Target Length: 17
# i = 0, train_end = 5, test_start = 5, test_end = 6
# Product health8, Period 0 - MSE: 0.00, Predicted Unit Price: 89.99
# i = 1, train_end = 6, test_start = 6, test_end = 7
# Product health8, Period 1 - MSE: 0.00, Predicted Unit Price: 89.99
# i = 2, train_end = 7, test_start = 7, test_end = 8
# Product health8, Period 2 - MSE: 0.00, Predicted Unit Price: 89.99
# i = 3, train_end = 8, test_start = 8, test_end = 9
# Product health8, Period 3 - MSE: 0.00, Predicted Unit Price: 89.99
# i = 4, train_end = 9, test_start = 9, test_end = 10
# Product health8, Period 4 - MSE: 0.00, Predicted Unit Price: 89.99
# i = 5, train_end = 10, test_start = 10, test_end = 11
# Product health8, Period 5 - MSE: 0.00, Predicted Unit Price: 89.99
# i = 6, train_end = 11, test_start = 11, test_end = 12
# Product health8, Period 6 - MSE: 39.06, Predicted Unit Price: 89.99
# i = 7, train_end = 12, test_start = 12, test_end = 13
# Product health8, Period 7 - MSE: 0.00, Predicted Unit Price: 80.02829950166826
# i = 8, train_end = 13, test_start = 13, test_end = 14
# Product health8, Period 8 - MSE: 0.00, Predicted Unit Price: 79.99000000006167
# i = 9, train_end = 14, test_start = 14, test_end = 15
# Product health8, Period 9 - MSE: 0.00, Predicted Unit Price: 80.01615062747294
# i = 10, train_end = 15, test_start = 15, test_end = 16
# Product health8, Period 10 - MSE: 0.00, Predicted Unit Price: 79.98999999999992
# i = 11, train_end = 16, test_start = 16, test_end = 17
# Product health8, Period 11 - MSE: 0.00, Predicted Unit Price: 82.82142856999994
# Product health9 - Features Length: 18, Target Length: 18
# i = 0, train_end = 5, test_start = 5, test_end = 6
# Product health9, Period 0 - MSE: 0.00, Predicted Unit Price: 19.99
# i = 1, train_end = 6, test_start = 6, test_end = 7
# Product health9, Period 1 - MSE: 11.61, Predicted Unit Price: 19.99
# i = 2, train_end = 7, test_start = 7, test_end = 8
# Product health9, Period 2 - MSE: 2.61, Predicted Unit Price: 25.60541938428954
# i = 3, train_end = 8, test_start = 8, test_end = 9
# Product health9, Period 3 - MSE: 2.28, Predicted Unit Price: 22.481558064618888
# i = 4, train_end = 9, test_start = 9, test_end = 10
# Product health9, Period 4 - MSE: 7.87, Predicted Unit Price: 26.79499094402518
# i = 5, train_end = 10, test_start = 10, test_end = 11
# Product health9, Period 5 - MSE: 0.90, Predicted Unit Price: 23.043599171190913
# i = 6, train_end = 11, test_start = 11, test_end = 12
# Product health9, Period 6 - MSE: 10.44, Predicted Unit Price: 20.758591541253136
# i = 7, train_end = 12, test_start = 12, test_end = 13
# Product health9, Period 7 - MSE: 0.00, Predicted Unit Price: 23.990000000000006
# i = 8, train_end = 13, test_start = 13, test_end = 14
# Product health9, Period 8 - MSE: 0.00, Predicted Unit Price: 23.990000000000055
# i = 9, train_end = 14, test_start = 14, test_end = 15
# Product health9, Period 9 - MSE: 0.00, Predicted Unit Price: 23.99
# i = 10, train_end = 15, test_start = 15, test_end = 16
# Product health9, Period 10 - MSE: 0.00, Predicted Unit Price: 23.99000000000008
# i = 11, train_end = 16, test_start = 16, test_end = 17
# Product health9, Period 11 - MSE: 0.00, Predicted Unit Price: 23.99000000000002
# i = 12, train_end = 17, test_start = 17, test_end = 18
# Product health9, Period 12 - MSE: 0.00, Predicted Unit Price: 23.989999999999924
# Product perfumery1 - Features Length: 13, Target Length: 13
# i = 0, train_end = 5, test_start = 5, test_end = 6
# Product perfumery1, Period 0 - MSE: 0.00, Predicted Unit Price: 56.989999999999995
# i = 1, train_end = 6, test_start = 6, test_end = 7
# Product perfumery1, Period 1 - MSE: 0.00, Predicted Unit Price: 56.99
# i = 2, train_end = 7, test_start = 7, test_end = 8
# Product perfumery1, Period 2 - MSE: 0.00, Predicted Unit Price: 56.99
# i = 3, train_end = 8, test_start = 8, test_end = 9
# Product perfumery1, Period 3 - MSE: 0.00, Predicted Unit Price: 56.99
# i = 4, train_end = 9, test_start = 9, test_end = 10
# Product perfumery1, Period 4 - MSE: 42.25, Predicted Unit Price: 56.989999999999995
# i = 5, train_end = 10, test_start = 10, test_end = 11
# Product perfumery1, Period 5 - MSE: 0.03, Predicted Unit Price: 50.16568705672448
# i = 6, train_end = 11, test_start = 11, test_end = 12
# Product perfumery1, Period 6 - MSE: 0.00, Predicted Unit Price: 49.99000000000796
# i = 7, train_end = 12, test_start = 12, test_end = 13
# Product perfumery1, Period 7 - MSE: 0.00, Predicted Unit Price: 49.990000000000016
# Product perfumery2 - Features Length: 13, Target Length: 13
# i = 0, train_end = 5, test_start = 5, test_end = 6
# Product perfumery2, Period 0 - MSE: 130.68, Predicted Unit Price: 129.33134859287154
# i = 1, train_end = 6, test_start = 6, test_end = 7
# Product perfumery2, Period 1 - MSE: 41.90, Predicted Unit Price: 111.41606973394046
# i = 2, train_end = 7, test_start = 7, test_end = 8
# ...
# cool4                4             158.85    124.06
# cool5                1              99.99      0.00
# cool5                2              99.99      0.00
# cool5                3              99.99      0.00
# cool5                4              99.99      0.00
# cool5                5              99.99      0.00
# cool5                6              99.99      0.00
# garden6              3              56.25      1.33
# garden6              4              52.95      9.29
# garden6              5              50.01      0.29
# garden6              6              54.54      0.41
# garden6              7              53.46      0.19
# garden6              8              53.42      0.00
# garden6              9              49.90      0.00
# garden6             10              49.91      0.00
# garden6             11              49.91      0.00
# garden7              1              59.90      0.00
# garden7              2              59.90     73.58
# garden7              3              55.77      1.46
# garden7              4              52.77      8.26
# garden7              5              53.10      2.89
# garden7              6              55.54      2.69
# garden7              7              75.83    480.74
# garden7              8              52.69      0.05
# garden7              9              50.00      0.01
# garden7             10              50.33      0.18
# garden7             11              47.10      7.83
# garden8              1             179.99     16.00
# garden8              2             185.78      4.29
# garden8              3             183.30     18.50
# garden8              4             179.08     15.42
# garden8              5             176.57      5.91
# garden8              6             180.19      1.42
# garden8              7             178.18    367.89
# garden8              8             173.64   1199.71
# garden8              9             184.43   2064.05
# garden9              1              59.90      0.00
# garden9              2              59.90      0.00
# garden9              3              59.90     42.52
# garden9              4              56.64      0.76
# garden9              5              51.88      3.94
# garden9              6              50.80      0.05
# garden9              7              54.11      0.04
# garden9              8              56.09      4.81
# garden9              9              52.49      0.01
# garden9             10              48.65      1.57
# garden9             11              47.40      6.25
# garden9             12              50.71      0.66
# health1              1              84.99      0.00
# health1              2              84.99      0.00
# health1              3              84.99      0.00
# health1              4              84.99      0.00
# health10             1              49.73      3.16
# health10             2              50.00      0.50
# health2              1             325.00      0.00
# health2              2             325.00      0.00
# health2              3             325.00      0.80
# health2              4             332.54      6.44
# health2              5             325.60     19.35
# health2              6             328.17      3.34
# health2              7             330.33      0.11
# health2              8             331.32      1.74
# health3              1             132.70     94.25
# health3              2             122.32      0.46
# health3              3             120.53      6.06
# health4              1              29.90      0.00
# health4              2              29.90      0.00
# health4              3              29.90      0.00
# health4              4              29.90      0.00
# health4              5              29.90      0.00
# health4              6              29.90      0.00
# health5              1             349.90      0.00
# health5              2             349.90      0.00
# health5              3             349.90      0.00
# health5              4             349.90      0.00
# health5              5             349.90      0.00
# health5              6             349.90    770.82
# health5              7             337.53    152.93
# health5              8             345.37     20.52
# health5              9             349.90      0.00
# health5             10             349.90      0.00
# health5             11             349.90      0.00
# health5             12             351.18      1.14
# health5             13             364.21      0.04
# health5             14             364.19      0.04
# health5             15             362.16      3.39
# health6              1              67.10      0.01
# health6              2              66.65      0.11
# health7              1              64.99     38.32
# health7              2              57.99      1.62
# health7              3              55.45     12.51
# health7              4              58.89      0.01
# health7              5              60.61      2.64
# health7              6              60.63      2.69
# health7              7              58.85      0.02
# health7              8              58.99      0.00
# health7              9              58.99      0.00
# health7             10              58.99      0.00
# health7             11              58.99      0.00
# health7             12              58.99      0.00
# health7             13              58.99      0.00
# health7             14              58.99      0.00
# health7             15              58.99      0.00
# health8              1              89.99      0.00
# health8              2              89.99      0.00
# health8              3              89.99      0.00
# health8              4              89.99      0.00
# health8              5              89.99      0.00
# health8              6              89.99      0.00
# health8              7              89.99     39.06
# health8              8              80.03      0.00
# health8              9              79.99      0.00
# health8             10              80.02      0.00
# health8             11              79.99      0.00
    avg_predicted_price = entry[2]
    avg_mse = entry[3]
    product_avg_predicted_prices[group_key].append((avg_predicted_price, avg_mse, entry[1]))

# Find the optimal prices for each product ID based on minimum average MSE
optimal_prices = {}
for group_key, avg_mse_list in product_avg_predicted_prices.items():
    min_avg_mse_entry = min(avg_mse_list, key=lambda x: x[1])
    optimal_price = min_avg_mse_entry[0]
    min_mse = min_avg_mse_entry[1]
    min_mse_sample = min_avg_mse_entry[2]
    optimal_prices[group_key] = (optimal_price, min_mse, min_mse_sample)

# Prepare the final table data for optimal prices
optimal_table_data = []
for group_key, (optimal_price, min_mse, min_mse_sample) in optimal_prices.items():
    optimal_table_data.append([group_key, optimal_price, min_mse, min_mse_sample])

# Print the table for optimal prices
optimal_table_headers = ["Product ID", "Optimal Price", "Min MSE", "Sample with Min MSE"]
print(tabulate(optimal_table_data, headers=optimal_table_headers, floatfmt=(".0f", ".2f", ".2f", ".0f")))
# Out:
# Product ID      Optimal Price    Min MSE    Sample with Min MSE
# ------------  ---------------  ---------  ---------------------
# bed1                    45.95       0.00                      1
# bed2                    89.90       0.00                      1
# bed3                    84.89       0.00                      4
# bed4                    47.76       0.02                      2
# computers1              98.71       0.04                      1
# computers2              77.03       0.76                      5
# computers3             135.98       3.67                      1
# computers4             119.99       0.00                     12
# computers5              91.69      13.59                      1
# computers6             149.94       0.00                      1
# consoles1               36.20       0.00                      7
# consoles2               33.42       0.46                      4
# cool1                   99.99       0.00                      6
# cool2                  129.99       0.00                      6
# cool3                   60.89      16.86                      2
# cool4                  158.85     124.06                      4
# cool5                   99.99       0.00                      1
# furniture1              34.93       0.01                      8
# furniture2             103.23       0.00                      8
# furniture3              35.20       0.04                      7
# furniture4              99.90       0.00                      1
# garden1                117.61       5.73                      7
# garden10                59.90       0.00                      1
# garden2                 59.90       0.00                      1
# garden3                 98.36       2.65                     13
# garden4                 49.90       0.00                      9
# garden5                 99.29       3.81                      1
# garden6                 59.90       0.00                      1
# garden7                 59.90       0.00                      1
# garden8                180.19       1.42                      6
# garden9                 59.90       0.00                      1
# health1                 84.99       0.00                      1
# health10                50.00       0.50                      2
# health2                325.00       0.00                      1
# health3                122.32       0.46                      2
# health4                 29.90       0.00                      1
# health5                349.90       0.00                      1
# health6                 67.10       0.01                      1
# health7                 58.99       0.00                      9
# health8                 89.99       0.00                      1
# health9                 19.99       0.00                      1
# perfumery1              56.99       0.00                      2
# perfumery2             118.70       0.00                      7
# watches1               145.55       0.00                     12
# watches2               146.86       4.59                      2
# watches3                78.00       0.00                      1
# watches4               105.38       0.15                      3
# watches5               216.56       0.14                      3
# watches6               112.00       0.00                      9
# watches7               280.38       0.08                      4
# watches8               134.51     549.44                      5

# %%
table_df_4 = pd.DataFrame(table_data, columns=["Product ID", "Sample", "Predicted Price", "MSE"])
table_df_4.to_csv("Output/SW_predicted_prices_mse_cumulative.csv", index=False)

# %%
optimal_table_df_4 = pd.DataFrame(optimal_table_data, columns=["Product ID", "Optimal Price", "Min MSE", "Sample with Min MSE"])
optimal_table_df_4.to_csv("Output/RF_optimal_prices_cumulative.csv", index=False)
